# %% [markdown]
# 📌 Project Overview:
# This project focuses on geospatial analysis of restaurant data by mapping their locations using latitude and longitude. The dataset includes detailed information about restaurants such as name, city, address, cuisines, ratings, and coordinates.
#
# Objectives:
# Visualize restaurant locations on a scatter plot using their geographical coordinates.
#
# Identify geographic clusters or concentrations of restaurants.
#
# Compare distribution across cities to highlight areas with high or low restaurant density.
#
# Tools Used:
# Python for data analysis and visualization.
#
# Pandas for data manipulation.
#
# Seaborn & Matplotlib for plotting.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path =  (r"C:\Users\admin\Downloads\Dataset  (1).csv") # Update this path if necessary
df = pd.read_csv(file_path)

# Set up the plot style
sns.set(style="whitegrid")

# Plotting the locations of restaurants
plt.figure(figsize=(10, 8))
sns.scatterplot(
    data=df,
    x="Longitude",
    y="Latitude",
    hue="City",
    palette="tab10",
    legend='full',
    s=100
)

plt.title("Restaurant Locations by City")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.legend(title="City", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_6016\578499418.py:28: UserWarning: Glyph 65533 (\N{REPLACEMENT CHARACTER}) missing from current font.
#   plt.tight_layout()
# C:\Users\admin\AppData\Local\Temp\ipykernel_6016\578499418.py:28: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# C:\Users\admin\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65533 (\N{REPLACEMENT CHARACTER}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ✅ Conclusion:
# The scatter plot reveals clusters of restaurants concentrated in specific urban centers like Makati City and Mandaluyong City.
#
# These clusters are often aligned with commercial or high-traffic areas, suggesting potential opportunities for business expansion or marketing.
#
# Differences in restaurant spread between cities highlight urban planning and economic activity patterns.
#
# This type of spatial analysis can support location-based decision-making, such as site selection, targeted advertising, or delivery service optimization.
